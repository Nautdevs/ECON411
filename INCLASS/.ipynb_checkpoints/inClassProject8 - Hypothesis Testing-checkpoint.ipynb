# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
mut_data = pd.read_csv("Top100MutualFunds.csv")
mut_data
# Out:
#    Symbol                                               Name  Category1  \
# 0   AGTHX  American Funds The Growth Fund of America Class A  US Equity
# 1   FCNTX                           Fidelity Contrafund Fund  US Equity
# 2   CWMAX  American Funds Washington Mutual Investors Fun...  US Equity
# 3   CWMCX  American Funds Washington Mutual Investors Fun...  US Equity
# 4   CWMEX  American Funds Washington Mutual Investors Fun...  US Equity
# ..    ...                                                ...        ...
# 95  FDTRX                    Franklin DynaTech Fund Class R6  US Equity
# 96  FDYZX               Franklin DynaTech Fund Advisor Class  US Equity
# 97  BBVLX                Bridge Builder Large Cap Value Fund  US Equity
# 98  PEYAX                Putnam Large Cap Value Fund Class A  US Equity
# 99  TWCGX        American Century Growth Fund Investor Class  US Equity
#
#        Category2  Category3 Morningstar Category  Morningstar Rating  \
# ...

# %%
mut_data['Category3'].value_counts()
# Out:
# Large cap                 88
# Mid cap                    9
# Health care                1
# Communication Services     1
# Small cap                  1
# Name: Category3, dtype: int64

# %%
mut_data['Morningstar Rating'].value_counts(normalize=True)
# Out:
# 3.0    0.432990
# 4.0    0.350515
# 5.0    0.195876
# 2.0    0.020619
# Name: Morningstar Rating, dtype: float64

# %%
import pandas_datareader.data as web
import yfinance as yf
from datetime import datetime as dt

mut_dict = {}
symbols = list(mut_data["Symbol"])

start = dt(1980,1,1)
end = dt(2022,1,1)

# %%
yf.pdr_override()
fund_dat = web.get_data_yahoo(symbols,start,end)
# Out:
# [*********************100%***********************]  100 of 100 completed

# %%
close_dat = fund_dat["Adj Close"]
close_dat
# Out:
#                 AFMFX      AGTHX      AIVSX      AKRIX      AKRSX      AMCFX  \
# Date
# 1980-01-02        NaN   0.644044        NaN        NaN        NaN        NaN
# 1980-01-03        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-04        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-07        NaN   0.672127        NaN        NaN        NaN        NaN
# 1980-01-08        NaN   0.679616        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2021-12-27  50.308655  72.352432  48.986969  62.250618  62.654072  43.035316
# 2021-12-28  50.403755  72.006157  48.949265  62.250618  62.654072  42.831051
# 2021-12-29  50.574936  71.958061  49.015247  62.278820  62.682285  42.896046
# 2021-12-30  50.470322  71.900352  48.920986  62.288219  62.701092  42.849621
# 2021-12-31  50.517876  71.467506  48.826725  62.222416  62.625854  42.673206
#
# ...

# %%
close_dat['S&P 500'] = web.get_data_yahoo("^GSPC", start, end)["Adj Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-21-1fd1058a1ad0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_dat['S&P 500'] = web.get_data_yahoo("^GSPC", start, end)["Adj Close"]

# %%
close_dat
# Out:
#                 AFMFX      AGTHX      AIVSX      AKRIX      AKRSX      AMCFX  \
# Date
# 1980-01-02        NaN   0.644044        NaN        NaN        NaN        NaN
# 1980-01-03        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-04        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-07        NaN   0.672127        NaN        NaN        NaN        NaN
# 1980-01-08        NaN   0.679616        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2021-12-27  50.308655  72.352432  48.986969  62.250618  62.654072  43.035316
# 2021-12-28  50.403755  72.006157  48.949265  62.250618  62.654072  42.831051
# 2021-12-29  50.574936  71.958061  49.015247  62.278820  62.682285  42.896046
# 2021-12-30  50.470322  71.900352  48.920986  62.288219  62.701092  42.849621
# 2021-12-31  50.517876  71.467506  48.826725  62.222416  62.625854  42.673206
#
# ...

# %%
# yoy rates of changes are easier to interpret
yoy_ret = np.log(close_dat).diff(251)
fig,ax = plt.subplots(figsize=(25,15))
yoy_ret.plot.line(legend=False,color='k',alpha=.05,ax=ax)
ax.axhline(0, ls = '--', color = 'C2', linewidth=5)
yoy_ret["S&P 500"].plot.line(color="Red", linewidth=0.5,ax=ax)
# What happened in the first decade of the 2000s. Increased digitization? Futures became digitized, SOX happened.
# Out:
# <Axes: xlabel='Date'>

# %%
for year in range(1980,2022):
    year = str(year)
    print(close_dat.loc[str(year)].shape[0])
# Out:
# 253
# 253
# 253
# 253
# 253
# 252
# 253
# 253
# 253
# 252
# 253
# 253
# 254
# 253
# 252
# 252
# 254
# 253
# 252
# 252
# 252
# 248
# 252
# 252
# 252
# 252
# 251
# 251
# 253
# 252
# 252
# 252
# 250
# 252
# 252
# 252
# 252
# 251
# 251
# 252
# 253
# 252
